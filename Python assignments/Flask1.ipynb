# %% [markdown]
# ## Flask 1

# %% [markdown]
# 1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Ans : Flask is a web framework that provides libraries to build lightweight web applications in python.It helps to create web apis which can be accessed on the internet.
# Following are the advantages of flask :
# 1. Scalable :  We can start small but scale it too.
# 2. Flexible : The minimal nature of Flask and its aptitude for developing smaller web apps means that it’s even more flexible than Django
# 3. Easy to negotiate :  is easy to understand for web developers, not just saving them time and effort but also giving them more control over their code
# 4. Lightweight : In Flash each module acts as an independent building block, which can execute one part of the functionality. Together this means that the whole constituent parts of the structure are flexible, moveable, and testable on their own.
# 5. Documentation : Flask is well documneted with lots of examples available.

# %% [markdown]
# 2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# The code is as follows:
#
# <pre><code>from flask import Flask,request
#
# app = Flask(__name__)
#
# @app.route("/")
# def greeting():
#     return "Hello World!"
#
# if __name__ == "__main__":
#     app.run(host="0.0.0.0")</code></pre>

# %% [markdown]
# ![Screenshot (7).png](attachment:78457c13-16af-4093-940e-5ebec6cf721f.png)

# %% [markdown]
# 3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# **Ans : App Routing means mapping the URLs to a specific function that will handle the logic for that URL. Modern web frameworks use more meaningful URLs to help users remember the URLs and make navigation simpler. Example: In our application, the URL (“/”) is associated with the root URL.**

# %% [markdown]
# 4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %% [markdown]
# <pre><code>
# from flask import Flask,request
#
# app = Flask(__name__)
#
# @app.route("/")
# def greeting():
#     return """Company Name: ABC Corporation<br/>
#             Location: India<br/>
#             Contact Detail: 999-999-9999<br/>
#             """
# @app.route("/welcome")
# def welcome_func():
#     return "Welcome to ABC Corporation"
#
# if __name__ == "__main__":
#     app.run(host="0.0.0.0")
# </pre></code>

# %% [markdown]
# The root "/" page:

# %% [markdown]
# ![Screenshot (8).png](attachment:274ecda1-eb7e-41b7-956f-c147cff95d7c.png)

# %% [markdown]
# The /welcome page:

# %% [markdown]
# ![Screenshot (9).png](attachment:2fa0cce3-3f78-4535-be5b-d00238b466ae.png)

# %% [markdown]
# 5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# **Ans: The function that is used for URL binding is url_for().The url_for() function is very useful for dynamically building a URL for a specific function. The function accepts the name of a function as first argument, and one or more keyword arguments, each corresponding to the variable part of URL.**
# **The url_for() method, is used to prepare a URL, for a function dynamically, such that, changing URLs, in the application, is avoided.**

# %% [markdown]
# The code is as follows:

# %% [markdown]
# <pre><code>
# from flask import Flask, redirect, url_for
#
# app = Flask(__name__)
#
# @app.route("/")
# def home_page():
#     return "This is home page"
#
# @app.route('/accounttype/<Type>')
# def accounttype(Type):
#  return 'This is a %s account' % Type
#
#
# @app.route('/user/<name>')
# def userType(name):
#   if name =='premium':
#      return redirect(url_for('accounttype',Type = name))
#   else:
#     return redirect(url_for('accounttype',Type = name))
#
#
# if __name__ == '__main__':
#    app.run(debug = True)
# </pre></code>

# %% [markdown]
# ![Screenshot (10).png](attachment:a6243575-b756-48ff-a625-119f275174c9.png)
