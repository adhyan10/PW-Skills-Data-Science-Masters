# %% [markdown]
# ## Flask 2

# %% [markdown]
# 1. Explain GET and POST methods.

# %% [markdown]
# Ans:
# **GET() : GET is used to request data from a specified resource.It is important to note that the query string (name/value pairs) is sent in the URL of a GET request.This makes it less secure .GET requests are only used to request data and not modify it.It can be cached and bookmarked.**
# **example: example.html/?num1=value1**
#
# **POST() : POST is used to send data to a server to create/update a resource.The data sent to the server with POST is stored in the request body of the HTTP request.This makes it more secure.POST requests can never be bookmarked or cached.**
# **example:**
# POST /test/demo_form.html HTTP/1.1
# Host: w3schools.com
#
# name1=value1&name2=value2

# %% [markdown]
# 2.  Why is request used in Flask?

# %% [markdown]
# **Ans: In the client-server architecture, the request object contains all the data that is sent from the client to the server.
# The Request, in Flask, is an object that contains all the data sent from the Client to Server. This data can be recovered using the GET/POST Methods. POST is used when your application expects user input to be received by command or an HTTP request, while GET gets all the information before it even has a chance for submission.**
#
# **There are various attributes associated with the request objects. They are Form, Cookies, Args, Files, and Method.
# The form is used to create and return the form data from other application with POST.**

# %% [markdown]
# 3.  Why is redirect() used in Flask?

# %% [markdown]
# **Ans : As the name suggests it is used to redirect to a specific route.Flask class has a redirect() function. When called, it returns a response object and redirects the user to another target location with specified status code.**
# **Syntax:**
# **Flask.redirect(location, statuscode, response)**

# %% [markdown]
# 4.  What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# **Ans : In Flask application we create a folder named as templates which contains all the html files.**
# **Templates are files that contain static data as well as placeholders for dynamic data. A template is rendered with specific data to produce a final document. Flask uses the Jinja template library to render templates. In your application, you will use templates to render HTML which will display in the user's browser.**
#
# **render_template() : render_template is used to generate output from a template file based on the Jinja2 engine that is found in the application's templates folder.**

# %% [markdown]
# 5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# <pre><code>
# from flask import Flask,request ,render_template , jsonify
#
# app = Flask(__name__)
#
#
# @app.route('/')
# def home_page():
#     return render_template('index.html')
#
#
# @app.route('/math',methods=['POST'])
# def math_ops():
#     if(request.method == 'POST'):
#
#         fname = request.form['fname']
#         lname = request.form['lname']
#
#         result = "Hello "+ fname + " " + lname
#
#         return render_template('results.html' , result = result)
#
#
#
#
# @app.route('/postman_action',methods=['POST'])
# def form1():
#     if(request.method == 'POST'):
#
#         fname = request.json['fname']
#         lname = request.json['lname']
#
#         result = "Hello "+ fname + " " + lname
#
#         return jsonify(result)
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")
# </pre></code>

# %% [markdown]
# ![Screenshot%20%2811%29.png](attachment:Screenshot%20%2811%29.png)
